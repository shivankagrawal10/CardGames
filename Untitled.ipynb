# %%
import Cards

playerdeck = Cards.deck()

for x in range(52): # goes from 0 to 51
    playerdeck.pile[x].prop()

playerdeck.riffleshuffle(10)    
print("\n after shuffle")
for x in range(52): # goes from 0 to 51
    playerdeck.pile[x].prop()
# Out:
# Starting import random_measure
# Ending import random_measure
# ('red', 'diamond', '2')
# ('red', 'diamond', '3')
# ('red', 'diamond', '4')
# ('red', 'diamond', '5')
# ('red', 'diamond', '6')
# ('red', 'diamond', '7')
# ('red', 'diamond', '8')
# ('red', 'diamond', '9')
# ('red', 'diamond', '10')
# ('red', 'diamond', 'Jack')
# ('red', 'diamond', 'Queen')
# ('red', 'diamond', 'King')
# ('red', 'diamond', 'A')
# ('red', 'hearts', '2')
# ('red', 'hearts', '3')
# ('red', 'hearts', '4')
# ('red', 'hearts', '5')
# ('red', 'hearts', '6')
# ('red', 'hearts', '7')
# ('red', 'hearts', '8')
# ('red', 'hearts', '9')
# ('red', 'hearts', '10')
# ('red', 'hearts', 'Jack')
# ('red', 'hearts', 'Queen')
# ('red', 'hearts', 'King')
# ('red', 'hearts', 'A')
# ('black', 'clubs', '2')
# ('black', 'clubs', '3')
# ('black', 'clubs', '4')
# ('black', 'clubs', '5')
# ('black', 'clubs', '6')
# ('black', 'clubs', '7')
# ('black', 'clubs', '8')
# ('black', 'clubs', '9')
# ('black', 'clubs', '10')
# ('black', 'clubs', 'Jack')
# ('black', 'clubs', 'Queen')
# ('black', 'clubs', 'King')
# ('black', 'clubs', 'A')
# ('black', 'spades', '2')
# ('black', 'spades', '3')
# ('black', 'spades', '4')
# ('black', 'spades', '5')
# ('black', 'spades', '6')
# ('black', 'spades', '7')
# ('black', 'spades', '8')
# ('black', 'spades', '9')
# ('black', 'spades', '10')
# ('black', 'spades', 'Jack')
# ('black', 'spades', 'Queen')
# ('black', 'spades', 'King')
# ('black', 'spades', 'A')
#
#  after shuffle
# ('red', 'diamond', '6')
# ('red', 'diamond', '7')
# ('red', 'diamond', '8')
# ('red', 'diamond', '9')
# ('black', 'clubs', '10')
# ('red', 'diamond', '2')
# ('red', 'diamond', 'A')
# ('red', 'hearts', '2')
# ('black', 'clubs', '9')
# ('red', 'hearts', '10')
# ('black', 'spades', '4')
# ('red', 'hearts', '7')
# ('red', 'diamond', 'Queen')
# ('black', 'spades', '9')
# ('black', 'clubs', 'A')
# ('black', 'spades', '2')
# ('black', 'clubs', '4')
# ('black', 'spades', '6')
# ('black', 'spades', '7')
# ('black', 'spades', '8')
# ('black', 'clubs', 'Jack')
# ('black', 'clubs', 'Queen')
# ('red', 'hearts', '4')
# ('red', 'hearts', '5')
# ('black', 'spades', '5')
# ('red', 'hearts', '6')
# ('red', 'hearts', 'Jack')
# ('black', 'spades', 'Jack')
# ('black', 'spades', 'Queen')
# ('black', 'spades', 'King')
# ('red', 'diamond', 'King')
# ('black', 'clubs', '5')
# ('red', 'hearts', 'Queen')
# ('black', 'spades', '10')
# ('red', 'diamond', 'Jack')
# ('red', 'hearts', '3')
# ('black', 'spades', 'A')
# ('black', 'spades', '3')
# ('red', 'hearts', 'King')
# ('black', 'clubs', 'King')
# ('red', 'diamond', '4')
# ('black', 'clubs', '3')
# ('red', 'hearts', 'A')
# ('red', 'hearts', '8')
# ('red', 'hearts', '9')
# ('red', 'diamond', '3')
# ('black', 'clubs', '2')
# ('black', 'clubs', '6')
# ('black', 'clubs', '7')
# ('black', 'clubs', '8')
# ('red', 'diamond', '10')
# ('red', 'diamond', '5')
